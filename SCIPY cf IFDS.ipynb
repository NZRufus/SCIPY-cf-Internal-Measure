# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = pd.read_csv(r"C:\Users\RufusTurner\Documents\Python Scripts\Python Scripts\Continuous Improvement\df_n2.csv")

# %% [markdown]
# ## W50/W75 are values determined by SCIPY and FWHM/FWQM (Full Width Half or Quarter Measure) are the proprietary measures and should be equivalent i.e. W50 should be equivalent to FWHM.

# %%
df["Measure"].value_counts()
# Out:
# FWHM    542
# FWQM    542
# W50     525
# W75     525
# Name: Measure, dtype: int64

# %%
order = ["W50", "FWHM", "W75", "FWQM"]
sns.catplot(data=df, y="Peak_Width", x="Measure", kind="box", order = order);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
options = ['W50', 'FWHM']
df2 = df[df['Measure'].isin(options)] 
options2 = ['W75', 'FWQM']
df3 = df[df['Measure'].isin(options2)]

# %%
sns.catplot(data=df2, y="Peak_Width", x="Measure", kind="box", sym='');
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.catplot(data=df3, y="Peak_Width", x="Measure", kind="box", sym='');
# Out:
# <img src="data:image/png;base64,..." width="500">
