# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import math as ma
from scipy.interpolate import interp1d
from scipy.stats.stats import pearsonr
from scipy.optimize import leastsq
from matplotlib.ticker import ScalarFormatter
import os
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\RufusTurner\Documents\Python Scripts\Python Scripts\Continuous Improvement\A72457.csv")

# %%
df.head()
# Out:
#    Blockade Start Time (s)  Baseline Current (nA)  RMS Noise (pA)  \
# 0                     0.04                135.524           15.97
# 1                     0.08                135.525            4.01
# 2                     0.12                135.523            4.63
# 3                     0.23                135.528            4.35
# 4                     0.44                135.533            4.76
#
#    Voltage (V)  Stretch (mm)  Applied Pressure  Blockade Magnitude (nA)  \
# 0         -0.6         46.99              1000                    0.390
# 1         -0.6         46.99              1000                    0.499
# 2         -0.6         46.99              1000                    0.739
# 3         -0.6         46.99              1000                    0.393
# 4         -0.6         46.99              1000                    0.326
#
#    Blockade Duration (ms)  Blockade FWHM (ms)  Blockade FWQM (ms) Membrane
# ...

# %%
df=df.drop(["Baseline Current (nA)","Blockade Start Time (s)","Voltage (V)", "Stretch (mm)"], axis = 1)

# %%
dfmelt=df.melt('Membrane', value_name='value')

# %%
list = ["Blockade FWHM (ms)", "Blockade FWQM (ms)"]
filtered_data = dfmelt.loc[dfmelt['variable'].isin(list)]
sns.catplot(data=filtered_data,x="Membrane", y = "value", hue="Membrane");
# Out:
# <img src="data:image/png;base64,..." width="500">
